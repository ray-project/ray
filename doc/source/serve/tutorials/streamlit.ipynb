# %% [markdown]
# (streamlit-serve-tutorial)=
#
# # Building a Streamlit app with Ray Serve
#
# In this example, we will show you how to wrap a machine learning model served
# by Ray Serve in a [Streamlit application](https://streamlit.io/).
#
# Specifically, we're going to download a GPT-2 model from the `transformer` library,
# define a Ray Serve deployment with it, and then define and launch a Streamlit app.
# Let's take a look.

# %%
# Install all dependencies for this example.
! pip install ray streamlit transformers requests
# Out:
# Requirement already satisfied: ray in /Users/maxpumperla/code/anyscale/ray/doc/venv/lib/python3.7/site-packages (1.12.0)
# Requirement already satisfied: streamlit in /Users/maxpumperla/code/anyscale/ray/doc/venv/lib/python3.7/site-packages (1.8.1)
# Collecting transformers
#   Using cached transformers-4.18.0-py3-none-any.whl (4.0 MB)
# Requirement already satisfied: requests in /Users/maxpumperla/code/anyscale/ray/doc/venv/lib/python3.7/site-packages (2.27.1)
# Requirement already satisfied: aiosignal in /Users/maxpumperla/code/anyscale/ray/doc/venv/lib/python3.7/site-packages (from ray) (1.2.0)
# Requirement already satisfied: protobuf>=3.15.3 in /Users/maxpumperla/code/anyscale/ray/doc/venv/lib/python3.7/site-packages (from ray) (3.20.1)
# Requirement already satisfied: grpcio<=1.43.0,>=1.28.1 in /Users/maxpumperla/code/anyscale/ray/doc/venv/lib/python3.7/site-packages (from ray) (1.43.0)
# Requirement already satisfied: virtualenv in /Users/maxpumperla/code/anyscale/ray/doc/venv/lib/python3.7/site-packages (from ray) (20.14.1)
# Requirement already satisfied: click>=7.0 in /Users/maxpumperla/code/anyscale/ray/doc/venv/lib/python3.7/site-packages (from ray) (7.1.2)
# Requirement already satisfied: frozenlist in /Users/maxpumperla/code/anyscale/ray/doc/venv/lib/python3.7/site-packages (from ray) (1.3.0)
# Requirement already satisfied: pyyaml in /Users/maxpumperla/code/anyscale/ray/doc/venv/lib/python3.7/site-packages (from ray) (6.0)
# Requirement already satisfied: filelock in /Users/maxpumperla/code/anyscale/ray/doc/venv/lib/python3.7/site-packages (from ray) (3.6.0)
# Requirement already satisfied: jsonschema in /Users/maxpumperla/code/anyscale/ray/doc/venv/lib/python3.7/site-packages (from ray) (4.4.0)
# Requirement already satisfied: attrs in /Users/maxpumperla/code/anyscale/ray/doc/venv/lib/python3.7/site-packages (from ray) (21.4.0)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /Users/maxpumperla/code/anyscale/ray/doc/venv/lib/python3.7/site-packages (from ray) (1.0.3)
# Requirement already satisfied: numpy>=1.16 in /Users/maxpumperla/code/anyscale/ray/doc/venv/lib/python3.7/site-packages (from ray) (1.21.6)
# Requirement already satisfied: pandas>=0.21.0 in /Users/maxpumperla/code/anyscale/ray/doc/venv/lib/python3.7/site-packages (from streamlit) (1.3.5)
# Requirement already satisfied: toml in /Users/maxpumperla/code/anyscale/ray/doc/venv/lib/python3.7/site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: packaging in /Users/maxpumperla/code/anyscale/ray/doc/venv/lib/python3.7/site-packages (from streamlit) (21.3)
# Requirement already satisfied: typing-extensions in /Users/maxpumperla/code/anyscale/ray/doc/venv/lib/python3.7/site-packages (from streamlit) (4.2.0)
# Requirement already satisfied: importlib-metadata>=1.4 in /Users/maxpumperla/code/anyscale/ray/doc/venv/lib/python3.7/site-packages (from streamlit) (4.11.3)
# Requirement already satisfied: altair>=3.2.0 in /Users/maxpumperla/code/anyscale/ray/doc/venv/lib/python3.7/site-packages (from streamlit) (4.2.0)
# Requirement already satisfied: cachetools>=4.0 in /Users/maxpumperla/code/anyscale/ray/doc/venv/lib/python3.7/site-packages (from streamlit) (5.0.0)
# Requirement already satisfied: blinker in /Users/maxpumperla/code/anyscale/ray/doc/venv/lib/python3.7/site-packages (from streamlit) (1.4)
# Requirement already satisfied: validators in /Users/maxpumperla/code/anyscale/ray/doc/venv/lib/python3.7/site-packages (from streamlit) (0.18.2)
# Requirement already satisfied: python-dateutil in /Users/maxpumperla/code/anyscale/ray/doc/venv/lib/python3.7/site-packages (from streamlit) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in /Users/maxpumperla/code/anyscale/ray/doc/venv/lib/python3.7/site-packages (from streamlit) (9.1.0)
# Requirement already satisfied: tornado>=5.0 in /Users/maxpumperla/code/anyscale/ray/doc/venv/lib/python3.7/site-packages (from streamlit) (6.1)
# Requirement already satisfied: semver in /Users/maxpumperla/code/anyscale/ray/doc/venv/lib/python3.7/site-packages (from streamlit) (2.13.0)
# Requirement already satisfied: pympler>=0.9 in /Users/maxpumperla/code/anyscale/ray/doc/venv/lib/python3.7/site-packages (from streamlit) (1.0.1)
# Requirement already satisfied: pydeck>=0.1.dev5 in /Users/maxpumperla/code/anyscale/ray/doc/venv/lib/python3.7/site-packages (from streamlit) (0.7.1)
# Requirement already satisfied: gitpython!=3.1.19 in /Users/maxpumperla/code/anyscale/ray/doc/venv/lib/python3.7/site-packages (from streamlit) (3.1.27)
# Requirement already satisfied: tzlocal in /Users/maxpumperla/code/anyscale/ray/doc/venv/lib/python3.7/site-packages (from streamlit) (4.2)
# Requirement already satisfied: pyarrow in /Users/maxpumperla/code/anyscale/ray/doc/venv/lib/python3.7/site-packages (from streamlit) (7.0.0)
# Collecting regex!=2019.12.17
#   Downloading regex-2022.4.24-cp37-cp37m-macosx_10_9_x86_64.whl (289 kB)
#      |████████████████████████████████| 289 kB 1.7 MB/s eta 0:00:01
# Requirement already satisfied: tqdm>=4.27 in /Users/maxpumperla/code/anyscale/ray/doc/venv/lib/python3.7/site-packages (from transformers) (4.64.0)
# Collecting sacremoses
#   Using cached sacremoses-0.0.49-py3-none-any.whl (895 kB)
# Collecting huggingface-hub<1.0,>=0.1.0
#   Using cached huggingface_hub-0.5.1-py3-none-any.whl (77 kB)
# Collecting tokenizers!=0.11.3,<0.13,>=0.11.1
#   Downloading tokenizers-0.12.1-cp37-cp37m-macosx_10_11_x86_64.whl (3.6 MB)
#      |████████████████████████████████| 3.6 MB 2.9 MB/s eta 0:00:01
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/maxpumperla/code/anyscale/ray/doc/venv/lib/python3.7/site-packages (from requests) (1.26.9)
# Requirement already satisfied: idna<4,>=2.5 in /Users/maxpumperla/code/anyscale/ray/doc/venv/lib/python3.7/site-packages (from requests) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/maxpumperla/code/anyscale/ray/doc/venv/lib/python3.7/site-packages (from requests) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/maxpumperla/code/anyscale/ray/doc/venv/lib/python3.7/site-packages (from requests) (2.0.12)
# Requirement already satisfied: toolz in /Users/maxpumperla/code/anyscale/ray/doc/venv/lib/python3.7/site-packages (from altair>=3.2.0->streamlit) (0.11.2)
# Requirement already satisfied: jinja2 in /Users/maxpumperla/code/anyscale/ray/doc/venv/lib/python3.7/site-packages (from altair>=3.2.0->streamlit) (3.1.1)
# Requirement already satisfied: entrypoints in /Users/maxpumperla/code/anyscale/ray/doc/venv/lib/python3.7/site-packages (from altair>=3.2.0->streamlit) (0.4)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /Users/maxpumperla/code/anyscale/ray/doc/venv/lib/python3.7/site-packages (from gitpython!=3.1.19->streamlit) (4.0.9)
# Requirement already satisfied: smmap<6,>=3.0.1 in /Users/maxpumperla/code/anyscale/ray/doc/venv/lib/python3.7/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19->streamlit) (5.0.0)
# Requirement already satisfied: six>=1.5.2 in /Users/maxpumperla/code/anyscale/ray/doc/venv/lib/python3.7/site-packages (from grpcio<=1.43.0,>=1.28.1->ray) (1.16.0)
# Requirement already satisfied: zipp>=0.5 in /Users/maxpumperla/code/anyscale/ray/doc/venv/lib/python3.7/site-packages (from importlib-metadata>=1.4->streamlit) (3.8.0)
# Requirement already satisfied: importlib-resources>=1.4.0 in /Users/maxpumperla/code/anyscale/ray/doc/venv/lib/python3.7/site-packages (from jsonschema->ray) (5.7.1)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /Users/maxpumperla/code/anyscale/ray/doc/venv/lib/python3.7/site-packages (from jsonschema->ray) (0.18.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Users/maxpumperla/code/anyscale/ray/doc/venv/lib/python3.7/site-packages (from packaging->streamlit) (3.0.8)
# Requirement already satisfied: pytz>=2017.3 in /Users/maxpumperla/code/anyscale/ray/doc/venv/lib/python3.7/site-packages (from pandas>=0.21.0->streamlit) (2022.1)
# Requirement already satisfied: traitlets>=4.3.2 in /Users/maxpumperla/code/anyscale/ray/doc/venv/lib/python3.7/site-packages (from pydeck>=0.1.dev5->streamlit) (5.1.1)
# Requirement already satisfied: ipykernel>=5.1.2 in /Users/maxpumperla/code/anyscale/ray/doc/venv/lib/python3.7/site-packages (from pydeck>=0.1.dev5->streamlit) (6.13.0)
# Requirement already satisfied: ipywidgets>=7.0.0 in /Users/maxpumperla/code/anyscale/ray/doc/venv/lib/python3.7/site-packages (from pydeck>=0.1.dev5->streamlit) (7.7.0)
# Requirement already satisfied: debugpy>=1.0 in /Users/maxpumperla/code/anyscale/ray/doc/venv/lib/python3.7/site-packages (from ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (1.6.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in /Users/maxpumperla/code/anyscale/ray/doc/venv/lib/python3.7/site-packages (from ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (0.1.3)
# Requirement already satisfied: nest-asyncio in /Users/maxpumperla/code/anyscale/ray/doc/venv/lib/python3.7/site-packages (from ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (1.5.5)
# Requirement already satisfied: appnope in /Users/maxpumperla/code/anyscale/ray/doc/venv/lib/python3.7/site-packages (from ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (0.1.3)
# Requirement already satisfied: ipython>=7.23.1 in /Users/maxpumperla/code/anyscale/ray/doc/venv/lib/python3.7/site-packages (from ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (7.32.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /Users/maxpumperla/code/anyscale/ray/doc/venv/lib/python3.7/site-packages (from ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (7.3.0)
# Requirement already satisfied: psutil in /Users/maxpumperla/code/anyscale/ray/doc/venv/lib/python3.7/site-packages (from ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (5.9.0)
# Requirement already satisfied: jedi>=0.16 in /Users/maxpumperla/code/anyscale/ray/doc/venv/lib/python3.7/site-packages (from ipython>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (0.18.1)
# Requirement already satisfied: setuptools>=18.5 in /Users/maxpumperla/code/anyscale/ray/doc/venv/lib/python3.7/site-packages (from ipython>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (58.1.0)
# Requirement already satisfied: decorator in /Users/maxpumperla/code/anyscale/ray/doc/venv/lib/python3.7/site-packages (from ipython>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (5.1.1)
# Requirement already satisfied: backcall in /Users/maxpumperla/code/anyscale/ray/doc/venv/lib/python3.7/site-packages (from ipython>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (0.2.0)
# Requirement already satisfied: pickleshare in /Users/maxpumperla/code/anyscale/ray/doc/venv/lib/python3.7/site-packages (from ipython>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /Users/maxpumperla/code/anyscale/ray/doc/venv/lib/python3.7/site-packages (from ipython>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (3.0.29)
# Requirement already satisfied: pygments in /Users/maxpumperla/code/anyscale/ray/doc/venv/lib/python3.7/site-packages (from ipython>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (2.11.2)
# Requirement already satisfied: pexpect>4.3 in /Users/maxpumperla/code/anyscale/ray/doc/venv/lib/python3.7/site-packages (from ipython>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (4.8.0)
# Requirement already satisfied: nbformat>=4.2.0 in /Users/maxpumperla/code/anyscale/ray/doc/venv/lib/python3.7/site-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (5.3.0)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /Users/maxpumperla/code/anyscale/ray/doc/venv/lib/python3.7/site-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.2.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /Users/maxpumperla/code/anyscale/ray/doc/venv/lib/python3.7/site-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (1.1.0)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /Users/maxpumperla/code/anyscale/ray/doc/venv/lib/python3.7/site-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (3.6.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/maxpumperla/code/anyscale/ray/doc/venv/lib/python3.7/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (0.8.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/maxpumperla/code/anyscale/ray/doc/venv/lib/python3.7/site-packages (from jinja2->altair>=3.2.0->streamlit) (2.1.1)
# Requirement already satisfied: pyzmq>=22.3 in /Users/maxpumperla/code/anyscale/ray/doc/venv/lib/python3.7/site-packages (from jupyter-client>=6.1.12->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (22.3.0)
# Requirement already satisfied: jupyter-core>=4.9.2 in /Users/maxpumperla/code/anyscale/ray/doc/venv/lib/python3.7/site-packages (from jupyter-client>=6.1.12->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (4.10.0)
# Requirement already satisfied: fastjsonschema in /Users/maxpumperla/code/anyscale/ray/doc/venv/lib/python3.7/site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (2.15.3)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/maxpumperla/code/anyscale/ray/doc/venv/lib/python3.7/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/maxpumperla/code/anyscale/ray/doc/venv/lib/python3.7/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit) (0.2.5)
# Requirement already satisfied: notebook>=4.4.1 in /Users/maxpumperla/code/anyscale/ray/doc/venv/lib/python3.7/site-packages (from widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (6.4.11)
# Requirement already satisfied: prometheus-client in /Users/maxpumperla/code/anyscale/ray/doc/venv/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.14.1)
# Requirement already satisfied: argon2-cffi in /Users/maxpumperla/code/anyscale/ray/doc/venv/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (21.3.0)
# Requirement already satisfied: terminado>=0.8.3 in /Users/maxpumperla/code/anyscale/ray/doc/venv/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.13.3)
# Requirement already satisfied: Send2Trash>=1.8.0 in /Users/maxpumperla/code/anyscale/ray/doc/venv/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (1.8.0)
# Requirement already satisfied: nbconvert>=5 in /Users/maxpumperla/code/anyscale/ray/doc/venv/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (6.5.0)
# Requirement already satisfied: defusedxml in /Users/maxpumperla/code/anyscale/ray/doc/venv/lib/python3.7/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.7.1)
# Requirement already satisfied: bleach in /Users/maxpumperla/code/anyscale/ray/doc/venv/lib/python3.7/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (5.0.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in /Users/maxpumperla/code/anyscale/ray/doc/venv/lib/python3.7/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.8.4)
# Requirement already satisfied: tinycss2 in /Users/maxpumperla/code/anyscale/ray/doc/venv/lib/python3.7/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (1.1.1)
# Requirement already satisfied: jupyterlab-pygments in /Users/maxpumperla/code/anyscale/ray/doc/venv/lib/python3.7/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.2.2)
# Requirement already satisfied: beautifulsoup4 in /Users/maxpumperla/code/anyscale/ray/doc/venv/lib/python3.7/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (4.11.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/maxpumperla/code/anyscale/ray/doc/venv/lib/python3.7/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (1.5.0)
# Requirement already satisfied: nbclient>=0.5.0 in /Users/maxpumperla/code/anyscale/ray/doc/venv/lib/python3.7/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.5.13)
# Requirement already satisfied: argon2-cffi-bindings in /Users/maxpumperla/code/anyscale/ray/doc/venv/lib/python3.7/site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (21.2.0)
# Requirement already satisfied: cffi>=1.0.1 in /Users/maxpumperla/code/anyscale/ray/doc/venv/lib/python3.7/site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (1.15.0)
# Requirement already satisfied: pycparser in /Users/maxpumperla/code/anyscale/ray/doc/venv/lib/python3.7/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (2.21)
# Requirement already satisfied: soupsieve>1.2 in /Users/maxpumperla/code/anyscale/ray/doc/venv/lib/python3.7/site-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (2.3.2.post1)
# Requirement already satisfied: webencodings in /Users/maxpumperla/code/anyscale/ray/doc/venv/lib/python3.7/site-packages (from bleach->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.5.1)
# Requirement already satisfied: joblib in /Users/maxpumperla/code/anyscale/ray/doc/venv/lib/python3.7/site-packages (from sacremoses->transformers) (1.1.0)
# Requirement already satisfied: backports.zoneinfo in /Users/maxpumperla/code/anyscale/ray/doc/venv/lib/python3.7/site-packages (from tzlocal->streamlit) (0.2.1)
# Requirement already satisfied: pytz-deprecation-shim in /Users/maxpumperla/code/anyscale/ray/doc/venv/lib/python3.7/site-packages (from tzlocal->streamlit) (0.1.0.post0)
# Requirement already satisfied: tzdata in /Users/maxpumperla/code/anyscale/ray/doc/venv/lib/python3.7/site-packages (from pytz-deprecation-shim->tzlocal->streamlit) (2022.1)
# Requirement already satisfied: distlib<1,>=0.3.1 in /Users/maxpumperla/code/anyscale/ray/doc/venv/lib/python3.7/site-packages (from virtualenv->ray) (0.3.4)
# Requirement already satisfied: platformdirs<3,>=2 in /Users/maxpumperla/code/anyscale/ray/doc/venv/lib/python3.7/site-packages (from virtualenv->ray) (2.5.2)
# Installing collected packages: regex, tokenizers, sacremoses, huggingface-hub, transformers
# Successfully installed huggingface-hub-0.5.1 regex-2022.4.24 sacremoses-0.0.49 tokenizers-0.12.1 transformers-4.18.0
# WARNING: You are using pip version 21.2.4; however, version 22.0.4 is available.
# You should consider upgrading via the '/Users/maxpumperla/code/anyscale/ray/doc/venv/bin/python -m pip install --upgrade pip' command.

# %% [markdown]
# ## Deploying a model with Ray Serve
#
# To start off, we import Ray Serve, Streamlit, the `transformers` and `requests` libraries:

# %%
import streamlit as st
from ray import serve
from transformers import pipeline
import requests
# Out:
# 2022-04-26 11:46:08,662	INFO api.py:738 -- Connecting to existing Serve instance in namespace 'serve'.
# (ServeController pid=70529) 2022-04-26 11:46:08,593	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:08,697	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:08,801	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:08,905	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:09,010	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:09,114	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:09,219	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:09,323	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:09,428	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:09,532	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:09,637	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:09,742	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:09,847	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:09,954	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:10,060	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:10,166	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:10,273	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:10,377	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:10,484	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:10,590	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:10,695	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:10,800	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:10,906	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:11,014	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:11,119	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:11,225	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:11,333	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:11,439	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:11,545	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:11,651	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:11,757	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:11,864	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:11,970	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:12,077	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:12,183	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:12,289	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:12,393	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:12,499	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:12,605	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:12,711	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:12,819	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:12,926	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:13,031	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:13,138	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:13,245	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:13,352	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:13,459	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:13,566	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:13,673	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:13,779	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:13,886	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:13,992	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:14,097	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:14,204	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:14,311	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:14,417	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:14,522	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:14,628	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:14,735	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:14,841	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:14,947	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:15,053	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:15,160	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:15,266	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:15,373	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:15,479	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:15,585	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:15,691	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:15,795	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:15,901	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:16,006	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:16,109	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:16,214	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:16,321	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:16,427	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:16,533	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:16,638	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:16,744	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:16,851	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:16,956	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:17,063	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:17,169	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:17,276	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:17,383	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:17,491	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:17,596	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:17,702	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:17,807	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:17,913	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:18,019	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:18,124	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:18,231	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:18,339	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:18,446	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:18,552	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:18,659	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:18,765	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:18,872	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:18,978	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:19,083	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:19,188	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:19,293	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:19,399	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:19,505	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:19,610	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:19,716	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:19,823	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:19,927	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:20,032	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:20,137	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:20,242	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:20,348	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:20,453	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:20,559	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:20,667	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:20,774	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:20,881	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:20,986	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:21,091	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:21,197	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:21,303	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:21,409	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:21,515	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:21,620	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:21,727	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:21,833	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:21,937	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:22,043	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:22,148	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:22,254	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:22,360	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:22,466	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:22,573	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:22,677	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:22,782	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:22,886	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:22,991	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:23,096	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:23,200	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:23,305	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:23,410	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:23,515	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:23,622	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:23,730	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:23,837	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:23,942	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:24,049	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:24,154	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:24,260	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:24,367	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:24,473	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:24,578	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:24,687	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:24,794	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:24,899	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:25,006	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:25,112	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:25,220	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:25,326	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:25,434	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:25,539	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:25,645	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:25,751	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:25,859	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:25,963	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:26,069	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:26,176	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:26,280	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:26,386	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:26,491	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:26,596	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:26,703	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:26,811	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:26,918	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:27,024	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:27,130	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:27,236	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:27,343	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:27,452	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:27,559	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:27,665	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:27,774	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:27,880	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:27,987	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:28,093	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:28,200	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:28,306	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:28,414	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:28,520	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:28,626	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:28,734	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:28,840	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:28,947	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:29,054	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:29,161	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:29,267	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:29,371	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:29,475	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:29,580	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:29,685	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:29,789	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:29,895	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:30,000	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:30,105	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:30,210	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:30,315	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# *** SIGTERM received at time=1650966392 ***
# PC: @     0x7ff80d63545e  (unknown)  kevent
# [2022-04-26 11:46:32,810 E 70403 14281973] logging.cc:325: *** SIGTERM received at time=1650966392 ***
# [2022-04-26 11:46:32,810 E 70403 14281973] logging.cc:325: PC: @     0x7ff80d63545e  (unknown)  kevent

# %% [markdown]
# Next, we define a Ray Serve deployment with a GPT-2 model, by using the `@serve.deployment` decorator on a `model`
# function that takes a `request` argument.
# In this function we define a GPT-2 model with a call to `pipeline` and return the result of querying the model.
# Before defining the deployment, we start Ray Serve using `serve.start()`, and then proceed to deploy the model
# with `model.deploy()`.

# %%
if 'model' not in st.session_state:
    serve.start()

    @serve.deployment
    def model(request):
        language_model = pipeline("text-generation", model="gpt2")
        query = request.query_params["query"]
        return language_model(query, max_length=100)

    model.deploy()
    st.session_state['model'] = True

# %% [markdown]
# Note that we're using Streamlit's `session_state` to make sure the deployment only gets run once.
# If we didn't use such a mechanism, Streamlit would simply run the whole script again, which is not what we want.
#
# To test this deployment we use a simple `example` query to get a `response` from the model running
# on `localhost:8000/model`.
# The first time you use this endpoint, the model will be downloaded first, which can take a while to complete.
# Subsequent calls will be faster.

# %%
example = "What's the meaning of life?"
response = requests.get(f"http://localhost:8000/model?query={example}")
print(response.text)
# Out:
# 2022-04-26 11:45:26,738	INFO api.py:615 -- Updating deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:26,802	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:26,909	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:27,014	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:27,119	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:27,225	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:27,334	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:27,439	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:27,547	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:27,652	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:27,757	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:27,860	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:27,964	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:28,068	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /var/folders/y_/l41py1sx7bl5n30jygrsv0q40000gn/T/ipykernel_70403/1837302763.py in <module>
# ----> 1 model.deploy()
#       2 example = "What's the meaning of life?"
#       3 response = requests.get(f"http://localhost:8000/model?query={example}")
#       4 print(response.text)
#
# ~/code/anyscale/ray/doc/venv/lib/python3.7/site-packages/ray/serve/api.py in deploy(self, _blocking, *init_args, **init_kwargs)
#    1276             route_prefix=self.route_prefix,
#    1277             url=self.url,
# -> 1278             _blocking=_blocking,
#    1279         )
#    1280
#
# ~/code/anyscale/ray/doc/venv/lib/python3.7/site-packages/ray/serve/api.py in check(self, *args, **kwargs)
#     180         if self._shutdown:
#     181             raise RayServeException("Client has already been shut down.")
# --> 182         return f(self, *args, **kwargs)
#     183
#     184     return check
#
# ~/code/anyscale/ray/doc/venv/lib/python3.7/site-packages/ray/serve/api.py in deploy(self, name, deployment_def, init_args, init_kwargs, ray_actor_options, config, version, prev_version, route_prefix, url, _blocking)
#     384
#     385         if _blocking:
# --> 386             self._wait_for_deployment_healthy(name)
#     387             self.log_deployment_ready(name, version, url, tag)
#     388
#
# ~/code/anyscale/ray/doc/venv/lib/python3.7/site-packages/ray/serve/api.py in _wait_for_deployment_healthy(self, name, timeout_s)
#     318                 break
#     319             elif status.status == DeploymentStatus.UNHEALTHY:
# --> 320                 raise RuntimeError(f"Deployment {name} is UNHEALTHY: {status.message}")
#     321             else:
#     322                 # Guard against new unhandled statuses being added.
#
# RuntimeError: Deployment model is UNHEALTHY: Failed to update deployment:
# No module named 'aiorwlock'.
# (ServeController pid=70529) 2022-04-26 11:45:28,171	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:28,274	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:28,379	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:28,483	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:28,588	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:28,693	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:28,798	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:28,902	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:29,007	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:29,112	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:29,218	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:29,326	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:29,433	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:29,539	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:29,646	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:29,750	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:29,857	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:29,962	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:30,068	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:30,177	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:30,285	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:30,391	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:30,500	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:30,607	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:30,713	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:30,820	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:30,927	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:31,034	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:31,141	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:31,246	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:31,352	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:31,459	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:31,564	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:31,669	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:31,774	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:31,878	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:31,984	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:32,091	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:32,196	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:32,302	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:32,408	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:32,514	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:32,620	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:32,727	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:32,836	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:32,941	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:33,046	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:33,151	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:33,258	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:33,363	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:33,468	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:33,576	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:33,684	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:33,791	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:33,900	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:34,008	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:34,115	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:34,221	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:34,326	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:34,432	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:34,538	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:34,646	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:34,754	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:34,860	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:34,968	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:35,075	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:35,182	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:35,289	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:35,397	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:35,505	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:35,611	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:35,719	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:35,826	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:35,932	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:36,039	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:36,093	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:36,200	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:36,309	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:36,416	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:36,524	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:36,630	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:36,734	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:36,841	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:36,950	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:37,058	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:37,167	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:37,274	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:37,378	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:37,485	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:37,610	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:37,715	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:37,819	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:37,925	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:38,030	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:38,136	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:38,240	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:38,345	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:38,451	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:38,558	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:38,662	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:38,769	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:38,874	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:38,980	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:39,086	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:39,191	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:39,298	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:39,404	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:39,512	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:39,620	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:39,728	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:39,836	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:39,942	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:40,049	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:40,158	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:40,264	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:40,371	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:40,478	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:40,585	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:40,692	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:40,797	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:40,902	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:41,008	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:41,113	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:41,217	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:41,322	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:41,428	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:41,532	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:41,635	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:41,741	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:41,845	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:41,950	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:42,056	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:42,162	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:42,266	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:42,371	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:42,476	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:42,583	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:42,688	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:42,793	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:42,899	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:43,003	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:43,111	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:43,217	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:43,323	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:43,429	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:43,536	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:43,643	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:43,748	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:43,856	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:43,965	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:44,071	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:44,177	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:44,284	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:44,391	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:44,497	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:44,604	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:44,713	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:44,819	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:44,926	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:45,033	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:45,141	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:45,250	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:45,356	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:45,461	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:45,568	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:45,677	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:45,783	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:45,888	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:45,993	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:46,100	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:46,207	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:46,313	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:46,422	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:46,530	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:46,638	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:46,743	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:46,851	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:46,959	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:47,067	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:47,175	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:47,281	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:47,387	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:47,494	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:47,603	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:47,709	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:47,815	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:47,923	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:48,032	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:48,137	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:48,243	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:48,348	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:48,454	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:48,559	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:48,665	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:48,770	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:48,874	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:48,982	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:49,089	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:49,193	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:49,298	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:49,403	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:49,509	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:49,614	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:49,721	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:49,826	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:49,930	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:50,035	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:50,140	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model

# %% [markdown]
# ## Defining and launching a Streamlit app
#
# To define a streamlit app, let's first create a convenient wrapper that takes a `query` argument and returns
# the result of querying the GPT model.

# %%
def gpt2(query):
    response = requests.get(f"http://localhost:8000/model?query={query}")
    return response.json()[0]["generated_text"]
# Out:
# (ServeController pid=70529) 2022-04-26 11:45:50,245	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:50,350	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:50,455	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:50,562	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:50,666	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:50,771	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:50,876	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:50,981	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:51,089	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:51,195	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:51,299	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:51,407	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:51,514	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:51,622	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:51,729	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:51,837	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:51,944	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:52,053	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:52,159	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:52,264	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:52,371	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:52,480	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:52,587	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:52,693	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:52,798	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:52,903	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:53,011	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:53,118	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:53,225	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:53,332	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:53,439	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:53,545	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:53,652	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:53,759	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:53,867	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:53,973	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:54,081	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:54,188	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:54,294	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:54,402	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:54,509	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:54,616	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:54,723	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:54,828	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:54,933	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:55,039	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:55,147	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:55,255	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:55,363	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:55,470	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:55,576	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:55,683	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:55,789	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:55,894	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:56,000	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:56,106	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:56,213	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:56,317	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:56,424	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:56,529	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:56,635	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:56,743	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:56,849	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:56,954	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:57,060	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:57,165	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:57,273	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:57,380	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:57,488	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:57,595	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:57,700	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:57,804	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:57,910	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:58,015	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:58,121	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:58,226	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:58,330	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:58,435	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:58,540	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:58,644	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:58,749	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:58,853	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:58,958	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:59,064	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:59,168	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:59,273	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:59,378	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:59,483	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:59,588	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:59,693	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:59,800	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:45:59,906	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model
# (ServeController pid=70529) 2022-04-26 11:46:00,012	INFO deployment_state.py:1211 -- Adding 1 replicas to deployment 'model'. component=serve deployment=model

# %% [markdown]
# Apart from this `gpt2` function, the only other thing that we need is a way for users to specify the model input,
# and a way to display the result.
# Since our model takes text as input and output, this turns out to be pretty simple:

# %%
st.title("Serving a GPT-2 model")

query = st.text_input(label="Input prompt", value="What's the meaning of life?")

if st.button('Run model'):
    output = gpt2(query)

    st.header("Model output")
    st.text(output)

# %% [markdown]
# To serve this model with Streamlit, we use just a few simple text components, namely `st.title`, `st.header`, and
# `st.text` for output and `st.text_input` for getting the model input.
# We also use a button to trigger model inference for a new input prompt.
# There's much more you can do with Streamlit, but this is just a simple example.
#
# ```{margin}
# The [Streamlit API documentation](https://docs.streamlit.io/library/api-reference)
# covers all viable Streamlit components in detail.
# ```
#
# Finally, if you put everything we just did together in a single file called `streamlit_app.py`,
# you can run your Streamlit app with Ray Serve as follows:

# %%
streamlit run streamlit_app.py

# %% [markdown]
# This should launch an interface that you can interact with that looks like this:
#
# ```{image} https://raw.githubusercontent.com/ray-project/images/master/docs/serve/streamlit_serve_gpt.png
# ```
#
# To summarize, if you know the basics of Streamlit, it's straightforward to deploy a model with Ray Serve with it.
