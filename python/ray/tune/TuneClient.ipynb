# %%
from ray.tune.web_server import TuneClient

manager = TuneClient(tune_address="localhost", port_forward=4321)

x = manager.get_all_trials()

[((y["id"]), y["status"]) for y in x["trials"]]

x
# Out:
# {'trials': [{'id': '5eac2c78',
#    'trainable_name': 'exp',
#    'config': {'iterations': 100, 'height': 0.0, 'width': 0.0},
#    'status': 'TERMINATED',
#    'result': {'timesteps_total': 29,
#     'neg_mean_loss': -193.0,
#     'timesteps_this_iter': 1,
#     'done': True,
#     'episodes_total': None,
#     'experiment_id': '576fa86257d24330812c672b821590a9',
#     'date': '2019-02-22_16-30-34',
#     'timestamp': 1550881834,
#     'training_iteration': 29,
#     'time_this_iter_s': 1.0001721382141113,
#     'time_total_s': 29.0797119140625,
#     'pid': 65930,
#     'hostname': 'airbears2-10-142-33-83.airbears2.1918.berkeley.edu',
#     'node_ip': '10.142.33.83',
#     'config': {'iterations': 100, 'height': 0.0, 'width': 0.0},
#     'time_since_restore': 29.0797119140625,
#     'timesteps_since_restore': 29,
#     'iterations_since_restore': 29}},
#   {'id': 'd8b52e17',
#    'trainable_name': 'exp',
#    'config': {'iterations': 100,
#     'height': -0.861262779039137,
#     'width': -0.33439224849587773},
#    'status': 'TERMINATED',
#    'result': {'timesteps_total': 9,
#     'neg_mean_loss': -217.52273913915818,
#     'timesteps_this_iter': 1,
#     'done': True,
#     'episodes_total': None,
#     'experiment_id': '652d88ef4a5d44b2b2bf55518b45f7ac',
#     'date': '2019-02-22_16-30-15',
#     'timestamp': 1550881815,
#     'training_iteration': 10,
#     'time_this_iter_s': 1.0014851093292236,
#     'time_total_s': 10.021003007888794,
#     'pid': 65932,
#     'hostname': 'airbears2-10-142-33-83.airbears2.1918.berkeley.edu',
#     'node_ip': '10.142.33.83',
#     'config': {'iterations': 100,
#      'height': -0.861262779039137,
#      'width': -0.33439224849587773},
#     'time_since_restore': 10.021003007888794,
#     'timesteps_since_restore': 9,
#     'iterations_since_restore': 10}},
#   {'id': '03e119f3',
#    'trainable_name': 'exp',
#    'config': {'iterations': 100,
#     'height': 0.6266254242532387,
#     'width': 0.6616130657969034},
#    'status': 'TERMINATED',
#    'result': {'timesteps_total': 28,
#     'neg_mean_loss': -176.50876060902675,
#     'timesteps_this_iter': 1,
#     'done': True,
#     'episodes_total': None,
#     'experiment_id': '652ee780fc124c1794a3dbed29782993',
#     'date': '2019-02-22_16-30-33',
#     'timestamp': 1550881833,
#     'training_iteration': 28,
#     'time_this_iter_s': 1.0032460689544678,
#     'time_total_s': 28.08400583267212,
#     'pid': 65931,
#     'hostname': 'airbears2-10-142-33-83.airbears2.1918.berkeley.edu',
#     'node_ip': '10.142.33.83',
#     'config': {'iterations': 100,
#      'height': 0.6266254242532387,
#      'width': 0.6616130657969034},
#     'time_since_restore': 28.08400583267212,
#     'timesteps_since_restore': 28,
#     'iterations_since_restore': 28}},
#   {'id': '21dbfa3c',
#    'trainable_name': 'exp',
#    'config': {'iterations': 100,
#     'height': 0.33139496551694964,
#     'width': -1.6686122856833943},
#    'status': 'TERMINATED',
#    'result': {'timesteps_total': 28,
#     'neg_mean_loss': -182.162151303012,
#     'timesteps_this_iter': 1,
#     'done': True,
#     'episodes_total': None,
#     'experiment_id': 'cc4ee9b88c5b4b169c1ce8c7aa64d505',
#     'date': '2019-02-22_16-30-33',
#     'timestamp': 1550881833,
#     'training_iteration': 28,
#     'time_this_iter_s': 1.003180980682373,
#     'time_total_s': 28.052841663360596,
#     'pid': 65933,
#     'hostname': 'airbears2-10-142-33-83.airbears2.1918.berkeley.edu',
#     'node_ip': '10.142.33.83',
#     'config': {'iterations': 100,
#      'height': 0.33139496551694964,
#      'width': -1.6686122856833943},
#     'time_since_restore': 28.052841663360596,
#     'timesteps_since_restore': 28,
#     'iterations_since_restore': 28}},
#   {'id': 'a8ffe544',
#    'trainable_name': 'exp',
#    'config': {'iterations': 100,
#     'height': 0.6915282603562183,
#     'width': 0.47403036493662354},
#    'status': 'TERMINATED',
#    'result': {'timesteps_total': 14,
#     'neg_mean_loss': -174.5894504098338,
#     'timesteps_this_iter': 1,
#     'done': True,
#     'episodes_total': None,
#     'experiment_id': 'b503937e9717496fbf4fd94e95f1ec55',
#     'date': '2019-02-22_16-30-33',
#     'timestamp': 1550881833,
#     'training_iteration': 15,
#     'time_this_iter_s': 1.0007519721984863,
#     'time_total_s': 15.0293128490448,
#     'pid': 65946,
#     'hostname': 'airbears2-10-142-33-83.airbears2.1918.berkeley.edu',
#     'node_ip': '10.142.33.83',
#     'config': {'iterations': 100,
#      'height': 0.6915282603562183,
#      'width': 0.47403036493662354},
#     'time_since_restore': 15.0293128490448,
#     'timesteps_since_restore': 14,
#     'iterations_since_restore': 15}},
#   {'id': '5f4a3289',
#    'trainable_name': 'exp',
#    'config': {'iterations': 100,
#     'height': 1.467254529520658,
#     'width': 1.893071504543953},
#    'status': 'TERMINATED',
#    'result': {'timesteps_total': 16,
#     'neg_mean_loss': -155.96278053236438,
#     'timesteps_this_iter': 1,
#     'done': True,
#     'episodes_total': None,
#     'experiment_id': 'e1cc25861ddb410c9aa4fd6185c3daa9',
#     'date': '2019-02-22_16-30-55',
#     'timestamp': 1550881855,
#     'training_iteration': 17,
#     'time_this_iter_s': 1.0005438327789307,
#     'time_total_s': 17.04159164428711,
#     'pid': 65945,
#     'hostname': 'airbears2-10-142-33-83.airbears2.1918.berkeley.edu',
#     'node_ip': '10.142.33.83',
#     'config': {'iterations': 100,
#      'height': 1.467254529520658,
#      'width': 1.893071504543953},
#     'time_since_restore': 17.04159164428711,
#     'timesteps_since_restore': 16,
#     'iterations_since_restore': 17}},
#   {'id': '683ceb61',
#    'trainable_name': 'exp',
#    'config': {'iterations': 100,
#     'height': 7.232070226869029,
#     'width': -0.8624076809039665},
#    'status': 'TERMINATED',
#    'result': {'timesteps_total': 16,
#     'neg_mean_loss': -41.94246573312868,
#     'timesteps_this_iter': 1,
#     'done': True,
#     'episodes_total': None,
#     'experiment_id': '02118874d64d4a7f89ebbf8c70933791',
#     'date': '2019-02-22_16-30-55',
#     'timestamp': 1550881855,
#     'training_iteration': 17,
#     'time_this_iter_s': 1.0048298835754395,
#     'time_total_s': 17.029922246932983,
#     'pid': 65942,
#     'hostname': 'airbears2-10-142-33-83.airbears2.1918.berkeley.edu',
#     'node_ip': '10.142.33.83',
#     'config': {'iterations': 100,
#      'height': 7.232070226869029,
#      'width': -0.8624076809039665},
#     'time_since_restore': 17.029922246932983,
#     'timesteps_since_restore': 16,
#     'iterations_since_restore': 17}},
#   {'id': '767dbdba',
#    'trainable_name': 'exp',
#    'config': {'iterations': 100,
#     'height': 1.177167100467456,
#     'width': 0.975180428017613},
#    'status': 'TERMINATED',
#    'result': {'timesteps_total': 16,
#     'neg_mean_loss': -162.40022399735182,
#     'timesteps_this_iter': 1,
#     'done': True,
#     'episodes_total': None,
#     'experiment_id': 'c0b720d1d3b646348d421b24e83351b2',
#     'date': '2019-02-22_16-30-55',
#     'timestamp': 1550881855,
#     'training_iteration': 17,
#     'time_this_iter_s': 1.0047171115875244,
#     'time_total_s': 17.051806926727295,
#     'pid': 65943,
#     'hostname': 'airbears2-10-142-33-83.airbears2.1918.berkeley.edu',
#     'node_ip': '10.142.33.83',
#     'config': {'iterations': 100,
#      'height': 1.177167100467456,
#      'width': 0.975180428017613},
#     'time_since_restore': 17.051806926727295,
#     'timesteps_since_restore': 16,
#     'iterations_since_restore': 17}},
#   {'id': 'aff8f84a',
#    'trainable_name': 'exp',
#    'config': {'iterations': 100,
#     'height': -1.113356553787441,
#     'width': -0.25973098403948347},
#    'status': 'TERMINATED',
#    'result': {'timesteps_total': 9,
#     'neg_mean_loss': -225.15381533787027,
#     'timesteps_this_iter': 1,
#     'done': True,
#     'episodes_total': None,
#     'experiment_id': 'cde6ba3c1e5f4f3d90673de5273c0974',
#     'date': '2019-02-22_16-30-48',
#     'timestamp': 1550881848,
#     'training_iteration': 10,
#     'time_this_iter_s': 1.00313401222229,
#     'time_total_s': 10.028385639190674,
#     'pid': 65971,
#     'hostname': 'airbears2-10-142-33-83.airbears2.1918.berkeley.edu',
#     'node_ip': '10.142.33.83',
#     'config': {'iterations': 100,
#      'height': -1.113356553787441,
#      'width': -0.25973098403948347},
#     'time_since_restore': 10.028385639190674,
#     'timesteps_since_restore': 9,
#     'iterations_since_restore': 10}},
#   {'id': '5588aebe',
#    'trainable_name': 'exp',
#    'config': {'iterations': 100,
#     'height': 1.8635019735376408,
#     'width': 0.06651920569547637},
#    'status': 'RUNNING',
#    'result': {'timesteps_total': 35,
#     'neg_mean_loss': -144.3611035520202,
#     'timesteps_this_iter': 1,
#     'done': False,
#     'episodes_total': None,
#     'experiment_id': 'f9be893787d4493dbd8493a21b0be6aa',
#     'date': '2019-02-22_16-31-25',
#     'timestamp': 1550881885,
#     'training_iteration': 35,
#     'time_this_iter_s': 1.0026471614837646,
#     'time_total_s': 35.096137046813965,
#     'pid': 65972,
#     'hostname': 'airbears2-10-142-33-83.airbears2.1918.berkeley.edu',
#     'node_ip': '10.142.33.83',
#     'config': {'iterations': 100,
#      'height': 1.8635019735376408,
#      'width': 0.06651920569547637},
#     'time_since_restore': 35.096137046813965,
#     'timesteps_since_restore': 35,
#     'iterations_since_restore': 35}},
#   {'id': '0e9a0d9b',
#    'trainable_name': 'exp',
#    'config': {'iterations': 100,
#     'height': 10.823076796781352,
#     'width': -7.879263030654908},
#    'status': 'RUNNING',
#    'result': {'timesteps_total': 25,
#     'neg_mean_loss': 0.7864219915058754,
#     'timesteps_this_iter': 1,
#     'done': False,
#     'episodes_total': None,
#     'experiment_id': '29f91a79c28c4ea9943389646a97dd5c',
#     'date': '2019-02-22_16-31-24',
#     'timestamp': 1550881884,
#     'training_iteration': 26,
#     'time_this_iter_s': 1.0014028549194336,
#     'time_total_s': 26.079720735549927,
#     'pid': 65988,
#     'hostname': 'airbears2-10-142-33-83.airbears2.1918.berkeley.edu',
#     'node_ip': '10.142.33.83',
#     'config': {'iterations': 100,
#      'height': 10.823076796781352,
#      'width': -7.879263030654908},
#     'time_since_restore': 26.079720735549927,
#     'timesteps_since_restore': 25,
#     'iterations_since_restore': 26}},
#   {'id': 'a13add82',
#    'trainable_name': 'exp',
#    'config': {'iterations': 100,
#     'height': 11.675454616133049,
#     'width': 6.69688703880167},
#    'status': 'RUNNING',
#    'result': {'timesteps_total': 25,
#     'neg_mean_loss': -1.7066242028554814,
#     'timesteps_this_iter': 1,
#     'done': False,
#     'episodes_total': None,
#     'experiment_id': '96d4eba734514287b117babf405aed84',
#     'date': '2019-02-22_16-31-24',
#     'timestamp': 1550881884,
#     'training_iteration': 26,
#     'time_this_iter_s': 1.0041918754577637,
#     'time_total_s': 26.046956062316895,
#     'pid': 65989,
#     'hostname': 'airbears2-10-142-33-83.airbears2.1918.berkeley.edu',
#     'node_ip': '10.142.33.83',
#     'config': {'iterations': 100,
#      'height': 11.675454616133049,
#      'width': 6.69688703880167},
#     'time_since_restore': 26.046956062316895,
#     'timesteps_since_restore': 25,
#     'iterations_since_restore': 26}},
#   {'id': '5a35842f',
#    'trainable_name': 'exp',
#    'config': {'iterations': 100,
#     'height': 13.349812180050634,
#     'width': -1.0232596693446303},
#    'status': 'RUNNING',
#    'result': {'timesteps_total': 25,
#     'neg_mean_loss': 3.6005154681341214,
#     'timesteps_this_iter': 1,
#     'done': False,
#     'episodes_total': None,
#     'experiment_id': '86330c50ab0b4efb827991c9c4514904',
#     'date': '2019-02-22_16-31-24',
#     'timestamp': 1550881884,
#     'training_iteration': 26,
#     'time_this_iter_s': 1.0013842582702637,
#     'time_total_s': 26.050883054733276,
#     'pid': 65990,
#     'hostname': 'airbears2-10-142-33-83.airbears2.1918.berkeley.edu',
#     'node_ip': '10.142.33.83',
#     'config': {'iterations': 100,
#      'height': 13.349812180050634,
#      'width': -1.0232596693446303},
#     'time_since_restore': 26.050883054733276,
#     'timesteps_since_restore': 25,
#     'iterations_since_restore': 26}}]}

# %%
for y in x["trials"][-10:]:
    manager.stop_trial(y["id"])

# %%
import yaml

with open("../rllib/tuned_examples/hyperband-cartpole.yaml") as f:
    d = yaml.load(f)

# %%
name, spec = [x for x in d.items()][0]

# %%
manager.add_trial(name, spec)
