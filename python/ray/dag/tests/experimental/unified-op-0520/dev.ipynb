# %%
import os
os.chdir("/home/wxdeng/stbr-min")

# %%
# !ci/lint/format.sh
# Out:
# remote: Enumerating objects: 52, done.
# remote: Counting objects: 100% (36/36), done.
# remote: Compressing objects: 100% (19/19), done.
# remote: Total 52 (delta 20), reused 18 (delta 17), pack-reused 16 (from 2)
# Unpacking objects: 100% (52/52), 111.93 KiB | 2.19 MiB/s, done.
# From https://github.com/ray-project/ray
#  * branch                  master     -> FETCH_HEAD
#    8ea9457303..4267914531  master     -> upstream/master
# All done! ✨ 🍰 ✨
# 16 files left unchanged.
# Checking docstyle...
# Reformatted changed files. Please review and stage the changes.
# Files updated:
#
# python/ray/dag/tests/experimental/test_torch_tensor_dag.py
# python/ray/dag/tests/experimental/unified-op-0520/dev.ipynb

# %%
# !ci/lint/lint.sh pre_commit
# Out:
# + pre_commit
# + pip install -c python/requirements_compiled.txt pre-commit clang-format
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cpu
# Looking in links: https://data.pyg.org/whl/torch-2.3.0+cpu.html
# ...
# + HOOKS=(python-no-log-warn ruff check-added-large-files check-ast check-toml black prettier mypy rst-directive-colons rst-inline-touching-normal python-check-mock-methods clang-format shellcheck docstyle check-import-order check-cpp-files-inclusion end-of-file-fixer check-json trailing-whitespace cpplint buildifier buildifier-lint)
# + for HOOK in "${HOOKS[@]}"
# + pre-commit run python-no-log-warn --all-files --show-diff-on-failure
# [INFO] Initializing environment for https://github.com/pre-commit/pre-commit-hooks.
# [INFO] Initializing environment for https://github.com/astral-sh/ruff-pre-commit.
# [INFO] Initializing environment for https://github.com/jsh9/pydoclint.
# [INFO] Initializing environment for https://github.com/cpplint/cpplint.
# ...
