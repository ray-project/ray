# %% [markdown]
# # Hello Image Data

# %% [markdown]
# This tutorial demonstrates how to train an image classifier using TensorFlow and the [Ray AI Runtime](https://docs.ray.io/en/latest/ray-air/getting-started.html).
#
# You should be familiar with TensorFlow before starting this tutorial. If you need a refresher, read TensorFlow's [Convolutional Neural Network](https://www.tensorflow.org/tutorials/images/cnn) tutorial.

# %% [markdown]
# ## Before you begin

# %% [markdown]
# * Install the [Ray AI Runtime](https://docs.ray.io/en/latest/ray-air/getting-started.html). You'll need Ray 1.13 later to run this example.
#
# ```
# pip instsall 'ray[data,tune]'
# ```
#
# * Install `tensorflow` and `tensorflow-datasets`
#
# ```
# pip install tensorflow tensorflow-datasets
# ```

# %% [markdown]
# # Load and normalize CIFAR-10

# %%
import ray
from ray.data.datasource import SimpleTensorFlowDatasource
import tensorflow as tf

from tensorflow.keras import layers, models
import tensorflow_datasets as tfds


def train_dataset_factory():
    return tfds.load("cifar10", split=["train"], as_supervised=True)[0]

def test_dataset_factory():
    return tfds.load("cifar10", split=["test"], as_supervised=True)[0]

train_dataset = ray.data.read_datasource(  
    SimpleTensorFlowDatasource(), dataset_factory=train_dataset_factory
)
test_dataset = ray.data.read_datasource(SimpleTensorFlowDatasource(), dataset_factory=test_dataset_factory)
# Out:
# 2022-05-21 20:02:29,205	WARNING read_api.py:252 -- The number of blocks in this dataset (1) limits its parallelism to 1 concurrent tasks. This is much less than the number of available CPU slots in the cluster. Use `.repartition(n)` to increase the number of dataset blocks.
# (_prepare_read pid=13883) 2022-05-21 20:02:29,197	WARNING tensorflow_datasource.py:53 -- `SimpleTensorFlowDatasource` doesn't support parallel reads. The `parallelism` argument will be ignored.
# 2022-05-21 20:02:38,329	WARNING read_api.py:252 -- The number of blocks in this dataset (1) limits its parallelism to 1 concurrent tasks. This is much less than the number of available CPU slots in the cluster. Use `.repartition(n)` to increase the number of dataset blocks.
# (_prepare_read pid=13883) 2022-05-21 20:02:38,326	WARNING tensorflow_datasource.py:53 -- `SimpleTensorFlowDatasource` doesn't support parallel reads. The `parallelism` argument will be ignored.

# %%
def normalize_images(batch):
    return [(tf.cast(image, tf.float32) / 255.0, label) for image, label in batch]

# train_dataset = train_dataset.map_batches(normalize_images)
# test_dataset = test_dataset.map_batches(normalize_images)

from timeit import default_timer as timer

def f(dataset):
    print("Starting")
    start = timer()
    dataset.map_batches(normalize_images)
    print(timer() - start)

f(train_dataset)  # 1.8523165209999206 / 15.950762251000015
# Out:
# Starting
# Read->Map_Batches: 100%|██████████| 1/1 [00:15<00:00, 15.94s/it]
# 15.950762251000015

# %%
asdf
# Out:
# 8.611250868933269

# %%
import pandas as pd
from ray.data.extensions import TensorArray


```
train_dataset = torchvision.datasets.cifar10(download=True, transform=transform)
train_dataset = ray.data.read_torch(train_dataset, column_names=["image", "label"])
train_dataset

Dataset(num_blocks=1000, num_rows=10000, schema={image: TensorDtype, label: int64})
````

```
def train_dataset_factory():
    return tfds.load("cifar10", split=["train"], as_supervised=True)[0]

train_dataset = ray.data.read_datasource(  
    SimpleTensorFlowDatasource(), dataset_factory=train_dataset_factory
)

def convert_batch_to_pandas(batch):
    images = TensorArray([image.numpy() for image, _ in batch])
    labels = [label.numpy() for _, label in batch]

    df = pd.DataFrame({"image": images, "label": labels})

    return df
    

train_dataset = train_dataset.map_batches(convert_batch_to_pandas)
test_dataset = test_dataset.map_batches(convert_batch_to_pandas)

test_dataset

Dataset(num_blocks=1, num_rows=10000, schema={image: TensorDtype, label: int64})

```

def convert_batch_to_pandas(batch):
    images = TensorArray([image.numpy() for image, _ in batch])
    labels = [label.numpy() for _, label in batch]

    df = pd.DataFrame({"image": images, "label": labels})

    return df
    

train_dataset = train_dataset.map_batches(convert_batch_to_pandas)
test_dataset = test_dataset.map_batches(convert_batch_to_pandas)

test_dataset
# Out:
# Map_Batches:   0%|          | 0/1 [00:04<?, ?it/s](raylet) Spilled 4263 MiB, 32 objects, write throughput 813 MiB/s.
# Map_Batches: 100%|██████████| 1/1 [00:06<00:00,  6.30s/it]
# Map_Batches: 100%|██████████| 1/1 [00:00<00:00,  1.21it/s]
# Dataset(num_blocks=1, num_rows=10000, schema={image: TensorDtype, label: int64})

# %% [markdown]
# ## Train a convolutional neural network

# %%
def build_model():
    model = models.Sequential()
    def squeeze(input):
        print(input.shape)
        return tf.squeeze(input, axis=1)
    model.add(layers.Lambda(squeeze))
    model.add(layers.Conv2D(6, (5, 5), activation='relu', input_shape=(32, 32, 3)))
    model.add(layers.MaxPooling2D((2, 2)))
    model.add(layers.Conv2D(16, (5, 5), activation='relu'))
    model.add(layers.MaxPooling2D((2, 2)))
    model.add(layers.Flatten())
    model.add(layers.Dense(120, activation='relu'))
    model.add(layers.Dense(84, activation='relu'))
    model.add(layers.Dense(10))
    return model

# %%
from ray import train
from ray.train.tensorflow import prepare_dataset_shard


# Slower than Torch?

def train_loop_per_worker(config):
    dataset_shard = train.get_dataset_shard("train")
    strategy = tf.distribute.experimental.MultiWorkerMirroredStrategy()
    with strategy.scope():
        model = build_model()
        model.compile(optimizer='adam',
                    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
                    metrics=['accuracy'])
    
    for epoch in range(2):  # TODO: Change to 2 epochs
        tf_dataset = prepare_dataset_shard(
            dataset_shard.to_tf(
                feature_columns=["image"],
                label_column="label",
                output_signature=(
                    tf.TensorSpec(shape=(None, 1, 32, 32, 3), dtype=tf.float32),
                    tf.TensorSpec(shape=(None, 1), dtype=tf.uint8),
                ),
                batch_size=config["batch_size"],
                unsqueeze_label_tensor=True,
            )
        )
        model.fit(tf_dataset)
        train.save_checkpoint(epoch=epoch, model=model.get_weights())  # model_weights vs model confusing, in example

# %%
from ray.ml.train.integrations.tensorflow import TensorflowTrainer

trainer = TensorflowTrainer(
    train_loop_per_worker=train_loop_per_worker,
    train_loop_config={"batch_size": 2},
    datasets={"train": train_dataset},
    scaling_config={"num_workers": 2}
)
result = trainer.fit()
latest_checkpoint = result.checkpoint
# Out:
# == Status ==<br>Current time: 2022-05-21 18:39:36 (running for 00:06:23.47)<br>Memory usage on this node: 25.0/64.0 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/16 CPUs, 0/0 GPUs, 0.0/45.99 GiB heap, 0.0/2.0 GiB objects<br>Result logdir: /Users/balaji/ray_results/TensorflowTrainer_2022-05-21_18-33-13<br>Number of trials: 1/1 (1 TERMINATED)<br><table>
# <thead>
# <tr><th>Trial name                   </th><th>status    </th><th>loc            </th></tr>
# </thead>
# <tbody>
# <tr><td>TensorflowTrainer_25727_00000</td><td>TERMINATED</td><td>127.0.0.1:18850</td></tr>
# </tbody>
# </table><br><br>
# (raylet) 2022-05-21 18:33:14,184	INFO context.py:70 -- Exec'ing worker with command: exec /Users/balaji/GitHub/ray/.venv/bin/python /Users/balaji/GitHub/ray/.venv/lib/python3.8/site-packages/ray/workers/default_worker.py --node-ip-address=127.0.0.1 --node-manager-port=52605 --object-store-name=/tmp/ray/session_2022-05-21_16-05-51_439235_13824/sockets/plasma_store --raylet-name=/tmp/ray/session_2022-05-21_16-05-51_439235_13824/sockets/raylet --redis-address=None --storage=None --temp-dir=/tmp/ray --metrics-agent-port=64222 --logging-rotate-bytes=536870912 --logging-rotate-backup-count=5 --gcs-address=127.0.0.1:56352 --redis-password=5241590000000000 --startup-token=59 --runtime-env-hash=1215741992
# (raylet) 2022-05-21 18:33:19,263	INFO context.py:70 -- Exec'ing worker with command: exec /Users/balaji/GitHub/ray/.venv/bin/python /Users/balaji/GitHub/ray/.venv/lib/python3.8/site-packages/ray/workers/default_worker.py --node-ip-address=127.0.0.1 --node-manager-port=52605 --object-store-name=/tmp/ray/session_2022-05-21_16-05-51_439235_13824/sockets/plasma_store --raylet-name=/tmp/ray/session_2022-05-21_16-05-51_439235_13824/sockets/raylet --redis-address=None --storage=None --temp-dir=/tmp/ray --metrics-agent-port=64222 --logging-rotate-bytes=536870912 --logging-rotate-backup-count=5 --gcs-address=127.0.0.1:56352 --redis-password=5241590000000000 --startup-token=61 --runtime-env-hash=1215741992
# (raylet) 2022-05-21 18:33:19,263	INFO context.py:70 -- Exec'ing worker with command: exec /Users/balaji/GitHub/ray/.venv/bin/python /Users/balaji/GitHub/ray/.venv/lib/python3.8/site-packages/ray/workers/default_worker.py --node-ip-address=127.0.0.1 --node-manager-port=52605 --object-store-name=/tmp/ray/session_2022-05-21_16-05-51_439235_13824/sockets/plasma_store --raylet-name=/tmp/ray/session_2022-05-21_16-05-51_439235_13824/sockets/raylet --redis-address=None --storage=None --temp-dir=/tmp/ray --metrics-agent-port=64222 --logging-rotate-bytes=536870912 --logging-rotate-backup-count=5 --gcs-address=127.0.0.1:56352 --redis-password=5241590000000000 --startup-token=60 --runtime-env-hash=1215741992
# (BaseWorkerMixin pid=18854) WARNING:tensorflow:From /var/folders/gx/t32twm6x54dftn9b2wxcbl100000gn/T/ipykernel_13824/1615179602.py:9: _CollectiveAllReduceStrategyExperimental.__init__ (from tensorflow.python.distribute.collective_all_reduce_strategy) is deprecated and will be removed in a future version.
# (BaseWorkerMixin pid=18854) Instructions for updating:
# (BaseWorkerMixin pid=18854) use distribute.MultiWorkerMirroredStrategy instead
# (BaseWorkerMixin pid=18854) 2022-05-21 18:33:24.017417: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# (BaseWorkerMixin pid=18854) To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# (BaseWorkerMixin pid=18854) 2022-05-21 18:33:24.021859: I tensorflow/core/distributed_runtime/rpc/grpc_channel.cc:272] Initialize GrpcChannelCache for job worker -> {0 -> 127.0.0.1:53923, 1 -> 127.0.0.1:53924}
# (BaseWorkerMixin pid=18854) 2022-05-21 18:33:24.021989: I tensorflow/core/distributed_runtime/rpc/grpc_channel.cc:272] Initialize GrpcChannelCache for job worker -> {0 -> 127.0.0.1:53923, 1 -> 127.0.0.1:53924}
# (BaseWorkerMixin pid=18854) 2022-05-21 18:33:24.022687: I tensorflow/core/distributed_runtime/rpc/grpc_server_lib.cc:438] Started server with target: grpc://127.0.0.1:53923
# (BaseWorkerMixin pid=18854) E0521 18:33:24.038457000 123145412972544 fork_posix.cc:76]             Other threads are currently calling into gRPC, skipping fork() handlers
# (BaseWorkerMixin pid=18855) WARNING:tensorflow:From /var/folders/gx/t32twm6x54dftn9b2wxcbl100000gn/T/ipykernel_13824/1615179602.py:9: _CollectiveAllReduceStrategyExperimental.__init__ (from tensorflow.python.distribute.collective_all_reduce_strategy) is deprecated and will be removed in a future version.
# (BaseWorkerMixin pid=18855) Instructions for updating:
# (BaseWorkerMixin pid=18855) use distribute.MultiWorkerMirroredStrategy instead
# (BaseWorkerMixin pid=18855) 2022-05-21 18:33:24.017458: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# (BaseWorkerMixin pid=18855) To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# (BaseWorkerMixin pid=18855) 2022-05-21 18:33:24.021934: I tensorflow/core/distributed_runtime/rpc/grpc_channel.cc:272] Initialize GrpcChannelCache for job worker -> {0 -> 127.0.0.1:53923, 1 -> 127.0.0.1:53924}
# (BaseWorkerMixin pid=18855) 2022-05-21 18:33:24.022036: I tensorflow/core/distributed_runtime/rpc/grpc_channel.cc:272] Initialize GrpcChannelCache for job worker -> {0 -> 127.0.0.1:53923, 1 -> 127.0.0.1:53924}
# (BaseWorkerMixin pid=18855) 2022-05-21 18:33:24.023153: I tensorflow/core/distributed_runtime/rpc/grpc_server_lib.cc:438] Started server with target: grpc://127.0.0.1:53924
# (BaseWorkerMixin pid=18854) 2022-05-21 18:33:24.211264: W tensorflow/core/framework/dataset.cc:768] Input of GeneratorDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# (BaseWorkerMixin pid=18855) 2022-05-21 18:33:24.212603: W tensorflow/core/framework/dataset.cc:768] Input of GeneratorDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# (BaseWorkerMixin pid=18854) (None, 1, 32, 32, 3)
# (BaseWorkerMixin pid=18855) (None, 1, 32, 32, 3)
# (BaseWorkerMixin pid=18854) (None, 1, 32, 32, 3)
# (BaseWorkerMixin pid=18855) (None, 1, 32, 32, 3)
# (BaseWorkerMixin pid=18855) (None, 1, 32, 32, 3)
# (BaseWorkerMixin pid=18854) (None, 1, 32, 32, 3)
#       1/Unknown - 2s 2s/step - loss: 2.6434 - accuracy: 0.0000e+00
#       1/Unknown - 2s 2s/step - loss: 2.6434 - accuracy: 0.0000e+00
#      17/Unknown - 2s 6ms/step - loss: 2.3814 - accuracy: 0.0882
#      17/Unknown - 2s 6ms/step - loss: 2.3814 - accuracy: 0.0882
#      33/Unknown - 2s 6ms/step - loss: 2.3450 - accuracy: 0.0909
#      33/Unknown - 2s 6ms/step - loss: 2.3450 - accuracy: 0.0909
#      41/Unknown - 2s 6ms/step - loss: 2.3465 - accuracy: 0.0976
#      41/Unknown - 2s 6ms/step - loss: 2.3465 - accuracy: 0.0976
#      56/Unknown - 2s 7ms/step - loss: 2.3370 - accuracy: 0.1071
#      56/Unknown - 2s 7ms/step - loss: 2.3370 - accuracy: 0.1071
#      73/Unknown - 3s 7ms/step - loss: 2.3340 - accuracy: 0.0959
.pyenv/versions/3.8.12/lib/python3.8/multiprocessing/resource_tracker.py:216: UserWarning: resource_tracker: There appear to be 4 leaked semaphore objects to clean up at shutdown
# (BaseWorkerMixin pid=18854)   warnings.warn('resource_tracker: There appear to be %d '
# (BaseWorkerMixin pid=18855) Exception ignored in: <function Pool.__del__ at 0x1c5fdfd30>
# (BaseWorkerMixin pid=18855) Traceback (most recent call last):
# (BaseWorkerMixin pid=18855)   File "/Users/balaji/.pyenv/versions/3.8.12/lib/python3.8/multiprocessing/pool.py", line 268, in __del__
# (BaseWorkerMixin pid=18855)     self._change_notifier.put(None)
# (BaseWorkerMixin pid=18855)   File "/Users/balaji/.pyenv/versions/3.8.12/lib/python3.8/multiprocessing/queues.py", line 368, in put
# (BaseWorkerMixin pid=18855)     self._writer.send_bytes(obj)
# (BaseWorkerMixin pid=18855)   File "/Users/balaji/.pyenv/versions/3.8.12/lib/python3.8/multiprocessing/connection.py", line 200, in send_bytes
# (BaseWorkerMixin pid=18855)     self._send_bytes(m[offset:offset + size])
# (BaseWorkerMixin pid=18855)   File "/Users/balaji/.pyenv/versions/3.8.12/lib/python3.8/multiprocessing/connection.py", line 411, in _send_bytes
# (BaseWorkerMixin pid=18855)     self._send(header + buf)
# (BaseWorkerMixin pid=18855)   File "/Users/balaji/.pyenv/versions/3.8.12/lib/python3.8/multiprocessing/connection.py", line 368, in _send
# (BaseWorkerMixin pid=18855)     n = write(self._handle, buf)
# (BaseWorkerMixin pid=18855) OSError: [Errno 9] Bad file descriptor
# (BaseWorkerMixin pid=18855) Exception ignored in: <function Pool.__del__ at 0x1c5fdfd30>
# (BaseWorkerMixin pid=18855) Traceback (most recent call last):
# (BaseWorkerMixin pid=18855)   File "/Users/balaji/.pyenv/versions/3.8.12/lib/python3.8/multiprocessing/pool.py", line 268, in __del__
# (BaseWorkerMixin pid=18855)     self._change_notifier.put(None)
# (BaseWorkerMixin pid=18855)   File "/Users/balaji/.pyenv/versions/3.8.12/lib/python3.8/multiprocessing/queues.py", line 368, in put
# (BaseWorkerMixin pid=18855)     self._writer.send_bytes(obj)
# (BaseWorkerMixin pid=18855)   File "/Users/balaji/.pyenv/versions/3.8.12/lib/python3.8/multiprocessing/connection.py", line 200, in send_bytes
# (BaseWorkerMixin pid=18855)     self._send_bytes(m[offset:offset + size])
# (BaseWorkerMixin pid=18855)   File "/Users/balaji/.pyenv/versions/3.8.12/lib/python3.8/multiprocessing/connection.py", line 411, in _send_bytes
# (BaseWorkerMixin pid=18855)     self._send(header + buf)
# (BaseWorkerMixin pid=18855)   File "/Users/balaji/.pyenv/versions/3.8.12/lib/python3.8/multiprocessing/connection.py", line 368, in _send
# (BaseWorkerMixin pid=18855)     n = write(self._handle, buf)
# (BaseWorkerMixin pid=18855) OSError: [Errno 9] Bad file descriptor

# %% [markdown]
# ## Test the network on the test data

# %%
from ray.ml.preprocessor import Preprocessor
from ray.ml.predictors.integrations.tensorflow import TensorflowPredictor
from ray.ml.batch_predictor import BatchPredictor
batch_predictor = BatchPredictor.from_checkpoint(
    checkpoint=latest_checkpoint,
    predictor_cls=TensorflowPredictor,
    model_definition=build_model,
)

    
outputs: ray.data.Dataset = batch_predictor.predict(
    data=test_dataset, feature_columns=["image"])
outputs.show(1)

# Save checkpoint to file?


mydf = None
# Out:
# Map Progress (1 actors 1 pending):   0%|          | 0/1 [00:04<?, ?it/s](BlockWorker pid=25353) 2022-05-21 19:26:47.045642: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# (BlockWorker pid=25353) To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# (BlockWorker pid=25353) (None, 1, 32, 32, 3)
# (BlockWorker pid=25353) (4096, 1, 32, 32, 3)
# (BlockWorker pid=25353) (None, 1, 32, 32, 3)
# (BlockWorker pid=25353) (4096, 1, 32, 32, 3)
# Map Progress (1 actors 1 pending): 100%|██████████| 1/1 [00:05<00:00,  5.05s/it]
# (BlockWorker pid=25353) (None, 1, 32, 32, 3)
# {'predictions': array([-0.78461206, -5.066856  , -0.20851843,  0.3337581 ,  0.7118397 ,
#         0.2990406 , -1.5815643 ,  0.49869645, -2.6954265 , -3.519926  ],
#       dtype=float32)}
# (BlockWorker pid=25353) (1808, 1, 32, 32, 3)

# %%
import numpy as np
def convert_logits_to_classes(df):
    best_class = df["predictions"].map(lambda x: x.argmax())
    df["prediction"] = best_class
    return df[["prediction"]]
predictions = outputs.map_batches(
    convert_logits_to_classes, batch_format="pandas"
)
# Out:
# Map_Batches: 100%|██████████| 1/1 [00:00<00:00, 23.27it/s]

# %%
def calculate_prediction_scores(df):
    df["correct"] = df["prediction"] == df["label"]
    return df[["prediction", "label", "correct"]]
scores = test_dataset.zip(predictions).map_batches(calculate_prediction_scores)
scores.show(1)
# Out:
# Map_Batches: 100%|██████████| 1/1 [00:00<00:00, 16.36it/s]
# {'prediction': 4, 'label': 7, 'correct': False}

# %%
scores.sum(on="correct") / scores.count()
# Out:
# Shuffle Map: 100%|██████████| 1/1 [00:00<00:00, 47.96it/s]
# Shuffle Reduce: 100%|██████████| 1/1 [00:00<00:00, 93.84it/s]
# 0.4722

# %%
test_dataset.count()
# Out:
# 10000

# %%
df = next(train_dataset.iter_batches(batch_size=4096, batch_format="pandas"))

# %%
import numpy as np
values = np.stack([col.to_numpy() for _, col in df.items()], axis=1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/balaji/GitHub/ray/python/ray/ml/examples/tensorflow/tensorflow_image_example.ipynb Cell 16' in <cell line: 2>()
#       <a href='vscode-notebook-cell:/Users/balaji/GitHub/ray/python/ray/ml/examples/tensorflow/tensorflow_image_example.ipynb#ch0000023?line=0'>1</a> import numpy as np
# ----> <a href='vscode-notebook-cell:/Users/balaji/GitHub/ray/python/ray/ml/examples/tensorflow/tensorflow_image_example.ipynb#ch0000023?line=1'>2</a> values = np.stack([col.to_numpy() for _, col in df.items()], axis=1)
#
# File <__array_function__ internals>:180, in stack(*args, **kwargs)
#
# File ~/GitHub/ray/.venv/lib/python3.8/site-packages/numpy/core/shape_base.py:426, in stack(arrays, axis, out)
#     <a href='file:///Users/balaji/GitHub/ray/.venv/lib/python3.8/site-packages/numpy/core/shape_base.py?line=423'>424</a> shapes = {arr.shape for arr in arrays}
#     <a href='file:///Users/balaji/GitHub/ray/.venv/lib/python3.8/site-packages/numpy/core/shape_base.py?line=424'>425</a> if len(shapes) != 1:
# --> <a href='file:///Users/balaji/GitHub/ray/.venv/lib/python3.8/site-packages/numpy/core/shape_base.py?line=425'>426</a>     raise ValueError('all input arrays must have the same shape')
#     <a href='file:///Users/balaji/GitHub/ray/.venv/lib/python3.8/site-packages/numpy/core/shape_base.py?line=427'>428</a> result_ndim = arrays[0].ndim + 1
#     <a href='file:///Users/balaji/GitHub/ray/.venv/lib/python3.8/site-packages/numpy/core/shape_base.py?line=428'>429</a> axis = normalize_axis_index(axis, result_ndim)
#
# ValueError: all input arrays must have the same shape

# %%
model = build_model()
# Out:
# 2022-05-21 19:16:41.695390: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
type(x)
# Out:
# NoneType

# %%
from ray import serve
from ray.serve.model_wrappers import ModelWrapperDeployment
from ray.serve.http_adapters import json_to_ndarray, NdArray

def my_adapter(data: NdArray):
    print(data)
    assert False
    return np.array(data.array)
serve.start(detached=True)
deployment = ModelWrapperDeployment.options(name="my-deployment2")
deployment.deploy(TensorflowPredictor, latest_checkpoint, http_adapter=my_adapter, batching_params=False, model_definition=build_model)
# Out:
# (ServeController pid=26527) INFO 2022-05-21 19:54:15,056 controller 26527 deployment_state.py:1175 - Stopping 1 replicas of deployment 'my-deployment2' with outdated versions.
# (ServeController pid=26527) INFO 2022-05-21 19:54:17,236 controller 26527 deployment_state.py:1216 - Adding 1 replicas to deployment 'my-deployment2'.

# %%
batch = test_dataset.take(1)
array = np.expand_dims(np.array(batch[0]["image"]), axis=[0, 1])
array.dtype
# Out:
# dtype('float32')

# %%
import requests
payload = {"array": array.tolist()}
response = requests.post(deployment.url, json=payload)
response.json()
# Out:
# (my-deployment2 pid=28394) INFO 2022-05-21 19:54:24,374 my-deployment2 my-deployment2#SHGdCB replica.py:478 - HANDLE __call__ OK 0.3ms
# (HTTPProxyActor pid=26529) INFO 2022-05-21 19:54:24,375 http_proxy 127.0.0.1 http_proxy.py:315 - POST /my-deployment2 307 4.4ms
# (HTTPProxyActor pid=26529) INFO 2022-05-21 19:54:24,432 http_proxy 127.0.0.1 http_proxy.py:315 - POST /my-deployment2 422 50.7ms
# (my-deployment2 pid=28394) INFO 2022-05-21 19:54:24,430 my-deployment2 my-deployment2#SHGdCB replica.py:478 - HANDLE __call__ OK 47.2ms
# {'detail': [{'loc': ['body', 'array', 0],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 0],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 1],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 2],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 3],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 4],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 5],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 6],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 7],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 8],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 9],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 10],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 11],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 12],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 13],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 14],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 15],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 16],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 17],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 18],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 19],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 20],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 21],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 22],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 23],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 24],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 25],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 26],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 27],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 28],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 29],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 30],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 31],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 0, 0],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 0, 1],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 0, 2],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 0, 3],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 0, 4],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 0, 5],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 0, 6],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 0, 7],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 0, 8],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 0, 9],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 0, 10],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 0, 11],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 0, 12],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 0, 13],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 0, 14],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 0, 15],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 0, 16],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 0, 17],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 0, 18],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 0, 19],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 0, 20],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 0, 21],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 0, 22],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 0, 23],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 0, 24],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 0, 25],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 0, 26],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 0, 27],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 0, 28],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 0, 29],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 0, 30],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 0, 31],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 1, 0],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 1, 1],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 1, 2],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 1, 3],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 1, 4],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 1, 5],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 1, 6],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 1, 7],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 1, 8],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 1, 9],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 1, 10],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 1, 11],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 1, 12],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 1, 13],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 1, 14],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 1, 15],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 1, 16],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 1, 17],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 1, 18],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 1, 19],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 1, 20],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 1, 21],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 1, 22],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 1, 23],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 1, 24],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 1, 25],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 1, 26],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 1, 27],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 1, 28],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 1, 29],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 1, 30],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 1, 31],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 2, 0],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 2, 1],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 2, 2],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 2, 3],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 2, 4],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 2, 5],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 2, 6],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 2, 7],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 2, 8],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 2, 9],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 2, 10],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 2, 11],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 2, 12],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 2, 13],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 2, 14],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 2, 15],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 2, 16],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 2, 17],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 2, 18],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 2, 19],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 2, 20],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 2, 21],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 2, 22],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 2, 23],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 2, 24],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 2, 25],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 2, 26],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 2, 27],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 2, 28],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 2, 29],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 2, 30],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 2, 31],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 3, 0],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 3, 1],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 3, 2],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 3, 3],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 3, 4],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 3, 5],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 3, 6],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 3, 7],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 3, 8],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 3, 9],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 3, 10],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 3, 11],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 3, 12],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 3, 13],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 3, 14],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 3, 15],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 3, 16],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 3, 17],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 3, 18],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 3, 19],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 3, 20],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 3, 21],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 3, 22],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 3, 23],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 3, 24],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 3, 25],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 3, 26],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 3, 27],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 3, 28],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 3, 29],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 3, 30],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 3, 31],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 4, 0],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 4, 1],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 4, 2],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 4, 3],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 4, 4],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 4, 5],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 4, 6],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 4, 7],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 4, 8],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 4, 9],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 4, 10],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 4, 11],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 4, 12],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 4, 13],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 4, 14],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 4, 15],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 4, 16],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 4, 17],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 4, 18],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 4, 19],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 4, 20],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 4, 21],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 4, 22],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 4, 23],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 4, 24],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 4, 25],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 4, 26],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 4, 27],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 4, 28],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 4, 29],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 4, 30],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 4, 31],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 5, 0],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 5, 1],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 5, 2],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 5, 3],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 5, 4],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 5, 5],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 5, 6],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 5, 7],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 5, 8],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 5, 9],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 5, 10],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 5, 11],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 5, 12],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 5, 13],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 5, 14],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 5, 15],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 5, 16],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 5, 17],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 5, 18],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 5, 19],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 5, 20],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 5, 21],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 5, 22],
#    'msg': 'value is not a valid float',
#    'type': 'type_error.float'},
#   {'loc': ['body', 'array', 0, 0, 5,